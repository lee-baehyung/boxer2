# %% [markdown]
# # 당신은 마법사로서 처음으로 마법 주문을 배우기 시작했습니다. 🪄
# ### 주문은 텍스트 입력과 출력으로 이루어져 있습니다 !

# %% [markdown]
# # [문제 1] **"마법사의 이름 출력"**
# ### 사용자에게 이름을 입력받아, `환영합니다, [이름]님!` 이라는 문장을 출력하세요!
# #### 사용할 변수명 : `name`

# %%
"""
<예시>

입력 : 오즈
출력 : 환영합니다, 오즈님!
"""

# 하단에 코드를 작성하세요
name = input("이름을 입력하세요 : ")
print(f"환영합니다, {name}님!")
# Out:
# 이름을 입력하세요 : 배형
# 환영합니다, 배형님!

# %%
name = input("이름을 입력하세요 : ")
print(f"환영합니다, {name}님!")

# %% [markdown]
# # [문제 2] **"마법 주문을 외치세요"**
# ### 사용자로부터 마법 주문을 입력받아 `당신의 주문은 [magic_spell] 입니다.` 라고 출력하세요!
# #### 사용할 변수명 : `magic_spell`

# %%
"""
<예시>

입력 : 아브라카다브라
출력 : 당신의 주문은 아브라카다브라 입니다.
"""

# 하단에 코드를 작성하세요
magic_spell = input("마법 주문을 입력하세요 : ")
print(f"당신의 주문은 {magic_spell} 입니다.")
# Out:
# 마법 주문을 입력하세요 : 아브라카다브라
# 당신의 주문은 아브라카다브라 입니다.

# %%
magic_spell = input("마법 주문을 입력하세요 : ")
print(f"당신의 주문은 {magic_spell} 입니다.")

# %% [markdown]
# # [문제 3] **"마법 구슬의 합 계산"**
# ### 두 개의 숫자를 입력받아 합을 출력하세요.
# ### 사용할 변수명 : `bead1`, `bead2`

# %%
"""
<예시>

입력 : 3, 5
출력 : 8
"""

# 하단에 코드를 작성하세요
bead1 = int(input("첫번째 구슬의 숫자를 입력하세요 : "))
bead2 = int(input("두번째 구슬의 숫자를 입력하세요 : "))

print(f"두 구슬의 합은 {bead1 + bead2} 입니다.")
# Out:
# 첫번째 구슬의 숫자를 입력하세요 : 3
# 두번째 구슬의 숫자를 입력하세요 : 5
# 두 구슬의 합은 8 입니다.

# %% [markdown]
# # [문제 4] **"마법사의 나이 계산"**
# ### 태어난 연도를 입력받아 나이를 계산하고 출력하세요.
# ### 사용할 변수명 : `birth_year`

# %%
"""
<예시>

입력 : 2000
출력 : 당신의 나이는 24살입니다.
"""

# 하단에 코드를 작성하세요.
brith_year = int(input("태어난 연도를 입력하세요 : "))
print(f"당신의 나이는 {2024 - brith_year}살입니다.")
# Out:
# 태어난 연도를 입력하세요 : 2000
# 당신의 나이는 24살입니다.

# %% [markdown]
# # [문제 5] **"마법의 거울"**
# ### 입력받은 문장을 거꾸로 출력하세요.
# ### 사용할 변수명 : `sentence`

# %%
"""
<예시>

입력 : 마법학교 입학을 축하합니다!
출력 : !다니합하축 을합입 교학법마
"""

# 하단에 코드를 작성하세요.
sentence = input("문장을 입력하세요 : ")
print(sentence[::-1])
# Out:
# 문장을 입력하세요 : 마법학교 입학을 축하합니다!
# !다니합하축 을학입 교학법마

# %% [markdown]
# # [문제 6] **"문장의 길이 계산"**
# ### 문제 5번에서 입력받은 문장의 글자수를 출력하세요.

# %%
"""
<예시>

입력 : 마법학교 입학을 축하합니다!
출력 : 15
"""

# 하단에 코드를 작성하세요.
sentence = input("문장을 입력하세요 : ")
print(len(sentence))
# Out:
# 문장을 입력하세요 : 마법학교 입학을 축하합니다!
# 15

# %% [markdown]
# # [문제 7] **"주문 속 단어 수 계산"**
# ### [문제 5,6]에서 입력 받은 문장에서 공백 기준으로 나눠진 단어의 개수를 출력하세요.

# %%
"""
<예시>

입력 : 마법학교 입학을 축하합니다!
출력 : 3
"""

# 하단에 코드를 작성하세요.
sentence = input("문장을 입력하세요 : ")
print(len(sentence.split()))
# Out:
# 문장을 입력하세요 : 마법학교 입학을 축하합니다!
# 3

# %% [markdown]
# # [문제 8] **"마법의 숫자 판별"**
# ### 입력받은 값이 숫자인지 확인하여, 숫자라면 True, 아니라면 False를 출력하세요.
# ### 사용할 변수명 : `magic_num`

# %%
"""
<에시>

입력 : 55
출력 : True
"""

# 하단에 코드를 입력하세요
magic_num = input("숫자를 입력하세요 : ")
print(magic_num.isdigit())
# Out:
# 숫자를 입력하세요 : 55
# True

# %% [markdown]
# # [문제 9] **"숲 속의 대소문자"**
# ### 입력받은 문자를 대문자는 소문자로, 소문자는 대문자로 변환하세요.
# ### 사용할 변수명 : `words`

# %%
"""
<예시>

입력 : AbCdEf
출력 : aBcDeF
"""

# 하단에 코드를 작성하세요.
words = input("문자를 입력하세요 : ")
print(words.swapcase())
# Out:
# 문자를 입력하세요 : AbCdEf
# aBcDeF

# %% [markdown]
# # [문제 10] **"암호화된 문장 출력"**
# ### 문자 하나를 입력받아, 문자의 아스키 값을 증가시킨 새로운 문장을 출력하세요.
# ### 사용할 변수명 : `word`

# %%
"""
<예시>

입력: a
출력: b
"""

# 하단에 코드를 작성하세요.
word = input("문자를 입력하세요 : ")
print(chr(ord(word) + 1))
# Out:
# 문자를 입력하세요 : a
# b
